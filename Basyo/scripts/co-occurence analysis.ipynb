# %%
import pandas as pd

# %%
df = pd.read_pickle('../../data/pickles/haiku_df.pickle')
df
# Out:
#            作者 フルネーム              俳句     季語   季節                    分かち書き  \
# 0      bashou  松尾芭蕉     姥桜さくや老後の思ひ出    NaN  NaN        姥桜 さく や 老後 の 思ひ 出
# 1      bashou  松尾芭蕉   年は人にとらせていつも若夷    NaN  NaN   年 は 人 に とら せ て いつも 若 夷
# 2      bashou  松尾芭蕉    花の顔に晴うてしてや朧月      花    春    花 の 顔 に 晴 うて し て や 朧月
# 3      bashou  松尾芭蕉     盛なる梅にす手引風も哉      梅    春      盛 なる 梅 に す 手引 風 も 哉
# 4      bashou  松尾芭蕉    あち東風や面々さばき柳髪     東風    春      あ ち 東風 や 面々 さばき 柳 髪
# ...       ...   ...             ...    ...  ...                      ...
# 14490  hisajo  杉田久女  田鶴舞ふや稲城の霜のけさ白く     稲城    秋  田鶴 舞 ふ や 稲城 の 霜 の けさ 白く
# 14491  hisajo  杉田久女    蔓ひけばこぼるる珠や冬苺      冬    冬    蔓 ひけ ば こ ぼ るる 珠 や 冬 苺
# 14492  hisajo  杉田久女   初雪の久住と相見て高嶺茶屋     初雪    冬    初雪 の 久住 と 相 見 て 高嶺 茶屋
# 14493  hisajo  杉田久女   クリスマス近づく寮の歌稽古  クリスマス    冬       クリスマス 近づく 寮 の 歌 稽古
# 14494  hisajo  杉田久女  北風吹くや月あきらかに港の灯     北風    冬   北風 吹く や 月 あきらか に 港 の 灯
#
#                   名詞        動詞  形容詞   副詞
# 0         姥桜 さく 老後 出        思ふ  NaN  NaN
# ...
